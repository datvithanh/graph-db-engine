# %%
import neomodel
from neomodel import config
from nodes import Food, ConsumerGroup
import pandas as pd
import numpy as np

# %%
config.DATABASE_URL = 'bolt://neo4j:123456@localhost:7687'

# %%
Food.nodes.get(name_en='egg')
# Out:
# <Food: {'name_en': 'egg', 'name_vi': 'trứng', 'id': 171}>

# %%
df = pd.read_csv('data/food_consumer_groups.csv')

# %%
df
# Out:
#    name_enfood                                                Old  \
# 0         beef  Sử dụng một lượng vừa phải thịt bò là hợp lý k...
# 1         pork  Thit lợn là nguồn dinh dưỡng cao, tuy vậy cũng...
# 2      chicken  Tiêu thụ một lượng thìt gà vừa đủ, nhất là phầ...
# 3         lamb  Thịt cừu cũng như một số loại thịt đỏ khác là ...
# 4       shrimp  Tôm cung cấp protein, bổ sung vitamin B12, và ...
# 5         crab  Cua có hàm lượng Natri và đạm cao, cùng với đó...
# 6          egg  Trứng có những chất đạm có giá trị sinh học ca...
# 7      lobster  Trứng có những chất đạm có giá trị sinh học ca...
# 8         veal  Sử dụng một lượng vừa phải thịt bê là hợp lý k...
# 9       banana  Chuối là nhóm trái cây giàu chất dinh dưỡng nh...
# 10       lemon                                                NaN
# 11      orange  Cam là loại trái cây rất giàu vitamin C, P, be...
# 12     avocado                                                NaN
# ...

# %%
di = {
    'elder': ('Old', 'OldStatus', 'Người già'),
    'teen': ('Teen', 'TeenStatus', 'Thanh thiếu niên'),
    'mature': ('Mature', 'MatureStatus', 'Người trưởng thành'),
    'child': ('Child', 'ChildStatus', 'Trẻ em'),
    'pregnant': ('Pregnant', 'PregnantStatus', 'Phụ nữ mang thai')
}

df = df.set_index('name_enfood')

# %%
foods = df.index

# %%
foods = list(foods)
foods
# Out:
# ['beef',
#  'pork',
#  'chicken',
#  'lamb',
#  'shrimp',
#  'crab',
#  'egg',
#  'lobster',
#  'veal',
#  'banana',
#  'lemon',
#  'orange',
#  'avocado',
#  'garlic',
#  'potato',
#  'apple',
#  'cabbage',
#  'broccoli',
#  'asparagus',
#  'yam',
#  'tomatoes']

# %%
for k,v in di.items():
    # comment the following line to import
    break
    consumer_group = ConsumerGroup(name_en = k, name_vi = v[-1]).save()
    for food in foods:
        if not (pd.isna(df[v[1]][food]) or pd.isna(df[v[0]][food])):
            print(df[v[1]][food].lower(), df[v[0]][food])
            try:
                food_node = Food.nodes.get(name_en=food)
            except:
                food_node = Food(name_en = 'apple', name_vi = 'Táo').save()
            food_node.consumer_groups.connect(consumer_group, {'description': df[v[0]][food], 'status': df[v[1]][food]})

# %% [markdown]
# # Import food-health issues

# %%
from nodes import HealthIssue
health_issues_dict = {
    'fever': 'Cảm cúm', 
    'vomiting': 'Nôn mửa', 
    'diarrhea': 'Tiêu chảy', 
    'diabetes': 'Tiểu đường', 
    'cardiovascular disease': 'Bệnh tim mạch', 
    'liver disease': 'Bệnh gan', 
    'obesity': 'Béo phì', 
    'cancer': 'Ung thư', 
    'weak bones': 'Xương yếu', 
    'weak immune system': 'Hệ miễn dịch yếu', 
    'stomachache': 'Đau bụng', 
    'high blood pressure': 'Huyết áp cao'
}

# %%
df = pd.read_csv('data/food_health_issues.csv')

# %%
df = df.set_index('name_enfood')

# %%
for k,v in health_issues_dict.items():
#     consumer_group = HealthIssue(name_en = k, name_vi = v).save()
    for food in foods:
#         if not (pd.isna(df[k][food]) or pd.isna(df[k][food])):
            
#             print(df[v[1]][food].lower(), df[v[0]][food])
#             try:
#                 food_node = Food.nodes.get(name_en=food)
#             except:
#                 food_node = Food(name_en = 'apple', name_vi = 'Táo').save()
#             food_node.consumer_groups.connect(consumer_group, {'description': df[v[0]][food], 'status': df[v[1]][food]})
# Out:
#   File "<ipython-input-13-41850183a9af>", line 11
#     #             food_node.consumer_groups.connect(consumer_group, {'description': df[v[0]][food], 'status': df[v[1]][food]})
#                                                                                                                               ^
# SyntaxError: unexpected EOF while parsing
